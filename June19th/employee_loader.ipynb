# %%
employee_data = [
    (101, "Vishal", "IT", 50000),
    (102, "Rahul", "HR", 45000),
    (103, "Priya", "Finance", 55000),
    (104, "Anu", "Marketing", 48000)
]

columns = ["emp_id", "name", "department", "salary"]

employee_df = spark.createDataFrame(employee_data, columns)

employee_df.show()

print("Employee Load Completed")
# Out:
# +------+------+----------+------+
# |emp_id|  name|department|salary|
# +------+------+----------+------+
# |   101|Vishal|        IT| 50000|
# |   102| Rahul|        HR| 45000|
# |   103| Priya|   Finance| 55000|
# |   104|   Anu| Marketing| 48000|
# +------+------+----------+------+
#
# Employee Load Completed
