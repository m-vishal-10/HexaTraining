# %%
customer_df = spark.table("customer_table")

summary_df = customer_df.groupBy("city").count()

summary_df.show()
# Out:
# +---------+-----+
# |     city|count|
# +---------+-----+
# |  Chennai|    2|
# |Bangalore|    2|
# |Hyderabad|    1|
# +---------+-----+
