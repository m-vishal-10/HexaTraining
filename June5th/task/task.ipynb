# %%
with open("C:\\Users\\Asus\\OneDrive\\Desktop\\HexaTraining\\June5th\\task\\employees.txt", "r") as file:
    employees = [line.strip().split(",") for line in file]

# %%
print(employees)
# Out:
# [['101', 'Rahul Sharma', 'Data Engineering', '75000', 'Hyderabad'], ['102', 'Priya Reddy', 'AI Engineering', '85000', 'Bangalore'], ['103', 'Amit Kumar', 'Data Engineering', '65000', 'Mumbai'], ['104', 'Sneha Patel', 'Data Science', '95000', 'Chennai'], ['105', 'Farhan Ali', 'Cloud Engineering', '80000', 'Delhi'], ['106', 'Neha Singh', 'AI Engineering', '72000', 'Hyderabad'], ['107', 'Arjun Verma', 'Data Engineering', '68000', 'Pune'], ['108', 'Meera Nair', 'Data Science', '90000', 'Bangalore'], ['109', 'Kiran Rao', 'Cloud Engineering', '78000', 'Hyderabad'], ['110', 'Ravi Kumar', 'AI Engineering', '82000', 'Mumbai']]

# %% [markdown]
# 1st exercise

# %%
with open("C:\\Users\\Asus\\OneDrive\\Desktop\\HexaTraining\\June5th\\task\\employees.txt", "r") as file:
    data = file.read()
    print(data)
# Out:
# 101,Rahul Sharma,Data Engineering,75000,Hyderabad
# 102,Priya Reddy,AI Engineering,85000,Bangalore
# 103,Amit Kumar,Data Engineering,65000,Mumbai
# 104,Sneha Patel,Data Science,95000,Chennai
# 105,Farhan Ali,Cloud Engineering,80000,Delhi
# 106,Neha Singh,AI Engineering,72000,Hyderabad
# 107,Arjun Verma,Data Engineering,68000,Pune
# 108,Meera Nair,Data Science,90000,Bangalore
# 109,Kiran Rao,Cloud Engineering,78000,Hyderabad
# 110,Ravi Kumar,AI Engineering,82000,Mumbai

# %% [markdown]
# 2nd exercise

# %%
with open("C:\\Users\\Asus\\OneDrive\\Desktop\\HexaTraining\\June5th\\task\\employees.txt", "r") as file:
    for line in file:
        print(line)
# Out:
# 101,Rahul Sharma,Data Engineering,75000,Hyderabad
#
# 102,Priya Reddy,AI Engineering,85000,Bangalore
#
# 103,Amit Kumar,Data Engineering,65000,Mumbai
#
# 104,Sneha Patel,Data Science,95000,Chennai
#
# 105,Farhan Ali,Cloud Engineering,80000,Delhi
#
# 106,Neha Singh,AI Engineering,72000,Hyderabad
#
# 107,Arjun Verma,Data Engineering,68000,Pune
#
# 108,Meera Nair,Data Science,90000,Bangalore
#
# 109,Kiran Rao,Cloud Engineering,78000,Hyderabad
#
# 110,Ravi Kumar,AI Engineering,82000,Mumbai

# %% [markdown]
# 3rd exercise

# %%
with open("C:\\Users\\Asus\\OneDrive\\Desktop\\HexaTraining\\June5th\\task\\employees.txt", "r") as file:
    count = 0
    for line in file:
        count += 1
    print(count)
# Out:
# 10

# %% [markdown]
# 4th

# %%
for emp in employees:
    print(emp[1])
# Out:
# Rahul Sharma
# Priya Reddy
# Amit Kumar
# Sneha Patel
# Farhan Ali
# Neha Singh
# Arjun Verma
# Meera Nair
# Kiran Rao
# Ravi Kumar

# %% [markdown]
# 5th

# %%
for emp in employees:
    if emp[4] == "Hyderabad":
        print(emp)
# Out:
# ['101', 'Rahul Sharma', 'Data Engineering', '75000', 'Hyderabad']
# ['106', 'Neha Singh', 'AI Engineering', '72000', 'Hyderabad']
# ['109', 'Kiran Rao', 'Cloud Engineering', '78000', 'Hyderabad']

# %% [markdown]
# 6th

# %%
for emp in employees:
    if emp[4] == "Bangalore":
        print(emp)
# Out:
# ['102', 'Priya Reddy', 'AI Engineering', '85000', 'Bangalore']
# ['108', 'Meera Nair', 'Data Science', '90000', 'Bangalore']

# %% [markdown]
# 7th

# %%
for emp in employees:
    if int(emp[3]) > 80000:
        print(emp)
# Out:
# ['102', 'Priya Reddy', 'AI Engineering', '85000', 'Bangalore']
# ['104', 'Sneha Patel', 'Data Science', '95000', 'Chennai']
# ['108', 'Meera Nair', 'Data Science', '90000', 'Bangalore']
# ['110', 'Ravi Kumar', 'AI Engineering', '82000', 'Mumbai']

# %% [markdown]
# 8th

# %%
highest_salary = max(int(emp[3]) for emp in employees)
print(highest_salary)
# Out:
# 95000

# %% [markdown]
# 9th

# %%
lowest_salary = min(int(emp[3]) for emp in employees)
print(lowest_salary)
# Out:
# 65000

# %% [markdown]
# 10th

# %%
avg_salary = sum(int(emp[3]) for emp in employees) / len(employees)
print(avg_salary)
# Out:
# 79000.0

# %% [markdown]
# 11th

# %%
total_salary = sum(int(emp[3]) for emp in employees)
print(total_salary)
# Out:
# 790000

# %% [markdown]
# 12th

# %%
count_ai = sum(1 for emp in employees if emp[2] == "AI Engineering")
print(count_ai)
# Out:
# 3

# %% [markdown]
# 13th

# %%
count_de = sum(1 for emp in employees if emp[2] == "Data Engineering")
print(count_de)
# Out:
# 3

# %% [markdown]
# 14th

# %%
for emp in employees:
    if emp[2] == "AI Engineering":
        print(emp)
# Out:
# ['102', 'Priya Reddy', 'AI Engineering', '85000', 'Bangalore']
# ['106', 'Neha Singh', 'AI Engineering', '72000', 'Hyderabad']
# ['110', 'Ravi Kumar', 'AI Engineering', '82000', 'Mumbai']

# %% [markdown]
# 15th

# %%
with open("C:\\Users\\Asus\\OneDrive\\Desktop\\HexaTraining\\June5th\\task\\high_salary_employees.txt", "w") as file:
    for emp in employees:
        if int(emp[3]) > 80000:
            file.write(",".join(emp) + "\n")

# %% [markdown]
# 16th

# %%
with open("C:\\Users\\Asus\\OneDrive\\Desktop\\HexaTraining\\June5th\\task\\hyderabad_employees.txt", "w") as file:
    for emp in employees:
        if emp[4] == "Hyderabad":
            file.write(",".join(emp) + "\n")

# %% [markdown]
# 17th

# %%
cities = set(emp[4] for emp in employees)
for city in cities:
    print(city)
# Out:
# Hyderabad
# Chennai
# Mumbai
# Pune
# Delhi
# Bangalore

# %% [markdown]
# 18th

# %%
dept_count = {}
for emp in employees:
    dept = emp[2]
    dept_count[dept] = dept_count.get(dept, 0) + 1

for dept, count in dept_count.items():
    print(dept, "=", count)
# Out:
# Data Engineering = 3
# AI Engineering = 3
# Data Science = 2
# Cloud Engineering = 2

# %% [markdown]
# 19th

# %%
highest_salary = max(int(emp[3]) for emp in employees)
for emp in employees:
    if int(emp[3]) == highest_salary:
        print(emp)
# Out:
# ['104', 'Sneha Patel', 'Data Science', '95000', 'Chennai']

# %% [markdown]
# 20th

# %%
with open("C:\\Users\\Asus\\OneDrive\\Desktop\\HexaTraining\\June5th\\task\\employee_report.txt", "w") as file:
    file.write(f"total employees: {len(employees)}\n")
    file.write(f"highest salary: {highest_salary}\n")
    file.write(f"lowest salary: {lowest_salary}\n")
    file.write(f"average salary: {avg_salary}\n")
    file.write(f"total salary: {total_salary}\n")
