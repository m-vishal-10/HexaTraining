# %%
a = 10
b = 0 
try:
    result = a/b 
    print(result)
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
# Out:
# Error: Division by zero is not allowed.

# %%
#another ex 

try:
    age = int(input("Enter your age: "))
    print(age)
except ValueError:
    print("Error: Please enter a valid integer for age.")
# Out:
# 10

# %%
#multiple exceptions
try:
    age = int(input("Enter your age: "))
    print(100/age)
except ValueError:
    print("Error: Please enter a valid integer for age.")
except ZeroDivisionError:
    print("Error: Age cannot be zero when calculating 100 divided by age.")
# Out:
# 8.333333333333334

# %%
#exception object 
try:
    num = int("abc")
except Exception as e:
    print(e)

#else block 
try:
    num = 10
    print(num)
except:
    print("error")
else:
    print("Success")

#finally 
try:
    print(10/0)
except:
    print("Error")
finally:
    print("connection closed")

#raise error
salary = -5000
if salary < 0:
    raise ValueError("Salary cannot be negative.")
# Out:
# invalid literal for int() with base 10: 'abc'
# 10
# Success
# Error
# connection closed
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 27
#      23
#      24 #raise error
#      25 salary = -5000
#      26 if salary < 0:
# ---> 27     raise ValueError("Salary cannot be negative.")
#      28
#
# ValueError: Salary cannot be negative.

# %% [markdown]
# FILE OPERATIONS

# %%
file = open("C:\\Users\\Asus\\OneDrive\\Desktop\\HexaTraining\\June5th\\practice\\employees.txt", "r")

print(file.read())
file.close()
# Out:
# Rahul Sharma
# Priya Reddy
# Amit Kumar
# Sneha Patel
# Farhan Ali
# Neha Singh
# Arjun Verma
# Meera Nair
# Kiran Rao
# Ravi Kumar

# %%
#right way
try:
    data = file.read()
    print(data)
except Exception as e:
    print(f"An error occurred: {e}")
finally:
    file.close()
# Out:
# An error occurred: I/O operation on closed file.

# %%
#read a single line 
file = open("C:\\Users\\Asus\\OneDrive\\Desktop\\HexaTraining\\June5th\\practice\\employees.txt", "r")

print(file.readline())
file.close()
# Out:
# Rahul Sharma

# %%
#read all lines
file = open("C:\\Users\\Asus\\OneDrive\\Desktop\\HexaTraining\\June5th\\practice\\employees.txt", "r")
lines = file.readlines()
print(lines)
file.close()
# Out:
# ['Rahul Sharma\n', 'Priya Reddy\n', 'Amit Kumar\n', 'Sneha Patel\n', 'Farhan Ali\n', 'Neha Singh\n', 'Arjun Verma\n', 'Meera Nair\n', 'Kiran Rao\n', 'Ravi Kumar']

# %%
#automatically close the file using with statement
with open("C:\\Users\\Asus\\OneDrive\\Desktop\\HexaTraining\\June5th\\practice\\employees.txt", "r") as file:
    data = file.read()
    print(data)
# Out:
# Rahul Sharma
# Priya Reddy
# Amit Kumar
# Sneha Patel
# Farhan Ali
# Neha Singh
# Arjun Verma
# Meera Nair
# Kiran Rao
# Ravi Kumar

# %%
#writing in file, executing this code again and again will only over write the same file
with open("C:\\Users\\Asus\\OneDrive\\Desktop\\HexaTraining\\June5th\\practice\\new_employees.txt", "w") as file:
    file.write("Rahul\n")
    file.write("Priya\n")

# %%
#append will not overwrite the file, adds new data at the end of the file
with open("C:\\Users\\Asus\\OneDrive\\Desktop\\HexaTraining\\June5th\\practice\\new_employees.txt", "a") as file:
    file.write("Vishal\n")
