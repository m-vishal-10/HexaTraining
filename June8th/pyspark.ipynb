# %%
# %pip install pyspark

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('PySpark Day 1').getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 from pyspark.sql import SparkSession
# ----> 2 spark = SparkSession.builder.appName('PySpark Day 1').getOrCreate()
#
# File c:\Users\Asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pyspark\sql\session.py:557, in SparkSession.Builder.getOrCreate(self)
#     555     sparkConf.set(key, value)
#     556 # This SparkContext may be an existing one.
# --> 557 sc = SparkContext.getOrCreate(sparkConf)
#     558 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559 # by all sessions.
#     560 session = SparkSession(sc, options=self._options)
#
# File c:\Users\Asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pyspark\core\context.py:542, in SparkContext.getOrCreate(cls, conf)
#     540 with SparkContext._lock:
# ...

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://5813f28a051d:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySpark Day 1</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
data = [
    (101, "Rahul Sharma", "Data Engineering", 75000, "Hyderabad"),
    (102, "Priya Reddy", "AI Engineering", 85000, "Bangalore"),
    (103, "Amit Kumar", "Data Engineering", 65000, "Mumbai"),
    (104, "Sneha Patel", "Data Science", 95000, "Chennai"),
    (105, "Farhan Ali", "Cloud Engineering", 80000, "Delhi")
]

# %%
columns = [
    "employee_id",
    "name",
    "department",
    "salary",
    "city"
]

# %%
df = spark.createDataFrame(data, columns)
df.show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# +-----------+------------+-----------------+------+---------+

# %%
df.printSchema()
# Out:
# root
#  |-- employee_id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- department: string (nullable = true)
#  |-- salary: long (nullable = true)
#  |-- city: string (nullable = true)

# %%
df.select(["name", "salary"]).show()
# Out:
# +------------+------+
# |        name|salary|
# +------------+------+
# |Rahul Sharma| 75000|
# | Priya Reddy| 85000|
# |  Amit Kumar| 65000|
# | Sneha Patel| 95000|
# |  Farhan Ali| 80000|
# +------------+------+

# %%
df.filter(df.salary > 80000).show()
# Out:
# +-----------+-----------+--------------+------+---------+
# |employee_id|       name|    department|salary|     city|
# +-----------+-----------+--------------+------+---------+
# |        102|Priya Reddy|AI Engineering| 85000|Bangalore|
# |        104|Sneha Patel|  Data Science| 95000|  Chennai|
# +-----------+-----------+--------------+------+---------+

# %%
df.filter(df.city == "Hyderabad").show()
# Out:
# +-----------+------------+----------------+------+---------+
# |employee_id|        name|      department|salary|     city|
# +-----------+------------+----------------+------+---------+
# |        101|Rahul Sharma|Data Engineering| 75000|Hyderabad|
# +-----------+------------+----------------+------+---------+

# %%
df.orderBy("salary").show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# +-----------+------------+-----------------+------+---------+

# %%
df.orderBy(df.salary.desc()).show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# +-----------+------------+-----------------+------+---------+

# %%
from pyspark.sql.functions import col

df_bonus = df.withColumn("bonus", col("salary")*0.10)
df_bonus.show()
# Out:
# +-----------+------------+-----------------+------+---------+------+
# |employee_id|        name|       department|salary|     city| bonus|
# +-----------+------------+-----------------+------+---------+------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|7500.0|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|8500.0|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|6500.0|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|9500.0|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|8000.0|
# +-----------+------------+-----------------+------+---------+------+

# %%
df_renamed = df.withColumnRenamed("salary", "monthly_salary")

df_renamed.show()
# Out:
# +-----------+------------+-----------------+--------------+---------+
# |employee_id|        name|       department|monthly_salary|     city|
# +-----------+------------+-----------------+--------------+---------+
# |        101|Rahul Sharma| Data Engineering|         75000|Hyderabad|
# |        102| Priya Reddy|   AI Engineering|         85000|Bangalore|
# |        103|  Amit Kumar| Data Engineering|         65000|   Mumbai|
# |        104| Sneha Patel|     Data Science|         95000|  Chennai|
# |        105|  Farhan Ali|Cloud Engineering|         80000|    Delhi|
# +-----------+------------+-----------------+--------------+---------+

# %%
df.groupBy("department").count().show()
# Out:
# +-----------------+-----+
# |       department|count|
# +-----------------+-----+
# | Data Engineering|    2|
# |   AI Engineering|    1|
# |Cloud Engineering|    1|
# |     Data Science|    1|
# +-----------------+-----+

# %% [markdown]
# Tasks

# %%
df.select(["employee_id", "name"]).show()
# Out:
# +-----------+------------+
# |employee_id|        name|
# +-----------+------------+
# |        101|Rahul Sharma|
# |        102| Priya Reddy|
# |        103|  Amit Kumar|
# |        104| Sneha Patel|
# |        105|  Farhan Ali|
# +-----------+------------+

# %%
df.select(["name", "salary", "city"]).show()
# Out:
# +------------+------+---------+
# |        name|salary|     city|
# +------------+------+---------+
# |Rahul Sharma| 75000|Hyderabad|
# | Priya Reddy| 85000|Bangalore|
# |  Amit Kumar| 65000|   Mumbai|
# | Sneha Patel| 95000|  Chennai|
# |  Farhan Ali| 80000|    Delhi|
# +------------+------+---------+

# %%
df.drop("city").show()
# Out:
# +-----------+------------+-----------------+------+
# |employee_id|        name|       department|salary|
# +-----------+------------+-----------------+------+
# |        101|Rahul Sharma| Data Engineering| 75000|
# |        102| Priya Reddy|   AI Engineering| 85000|
# |        103|  Amit Kumar| Data Engineering| 65000|
# |        104| Sneha Patel|     Data Science| 95000|
# |        105|  Farhan Ali|Cloud Engineering| 80000|
# +-----------+------------+-----------------+------+

# %%
df.filter(df.salary > 70000).show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# +-----------+------------+-----------------+------+---------+

# %%
df.filter(df.salary <80000).show()
# Out:
# +-----------+------------+----------------+------+---------+
# |employee_id|        name|      department|salary|     city|
# +-----------+------------+----------------+------+---------+
# |        101|Rahul Sharma|Data Engineering| 75000|Hyderabad|
# |        103|  Amit Kumar|Data Engineering| 65000|   Mumbai|
# +-----------+------------+----------------+------+---------+

# %%
df.filter(df.city == "Mumbai").show()
# Out:
# +-----------+----------+----------------+------+------+
# |employee_id|      name|      department|salary|  city|
# +-----------+----------+----------------+------+------+
# |        103|Amit Kumar|Data Engineering| 65000|Mumbai|
# +-----------+----------+----------------+------+------+

# %%
df.filter(df.city == "Bangalore").show()
# Out:
# +-----------+-----------+--------------+------+---------+
# |employee_id|       name|    department|salary|     city|
# +-----------+-----------+--------------+------+---------+
# |        102|Priya Reddy|AI Engineering| 85000|Bangalore|
# +-----------+-----------+--------------+------+---------+

# %%
df.filter(df.department == "Data Engineering").show()
# Out:
# +-----------+------------+----------------+------+---------+
# |employee_id|        name|      department|salary|     city|
# +-----------+------------+----------------+------+---------+
# |        101|Rahul Sharma|Data Engineering| 75000|Hyderabad|
# |        103|  Amit Kumar|Data Engineering| 65000|   Mumbai|
# +-----------+------------+----------------+------+---------+

# %%
df.filter(df.department == "AI Engineering").show()
# Out:
# +-----------+-----------+--------------+------+---------+
# |employee_id|       name|    department|salary|     city|
# +-----------+-----------+--------------+------+---------+
# |        102|Priya Reddy|AI Engineering| 85000|Bangalore|
# +-----------+-----------+--------------+------+---------+

# %%
df.filter(df.salary.between(70000, 90000)).show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# +-----------+------------+-----------------+------+---------+

# %%
df.filter((df.salary >70000) & (df.city == "Hyderabad")).show()
# Out:
# +-----------+------------+----------------+------+---------+
# |employee_id|        name|      department|salary|     city|
# +-----------+------------+----------------+------+---------+
# |        101|Rahul Sharma|Data Engineering| 75000|Hyderabad|
# +-----------+------------+----------------+------+---------+

# %%
df.filter((df.city == "Chennai") | (df.city == "Bangalore")).show()
# Out:
# +-----------+-----------+--------------+------+---------+
# |employee_id|       name|    department|salary|     city|
# +-----------+-----------+--------------+------+---------+
# |        102|Priya Reddy|AI Engineering| 85000|Bangalore|
# |        104|Sneha Patel|  Data Science| 95000|  Chennai|
# +-----------+-----------+--------------+------+---------+

# %%
df.filter(df.city.isin("Hyderabad", "Mumbai", "Delhi")).show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# +-----------+------------+-----------------+------+---------+

# %%
df.filter(df.department.isin("Data Engineering", "AI Engineering")).show()
# Out:
# +-----------+------------+----------------+------+---------+
# |employee_id|        name|      department|salary|     city|
# +-----------+------------+----------------+------+---------+
# |        101|Rahul Sharma|Data Engineering| 75000|Hyderabad|
# |        102| Priya Reddy|  AI Engineering| 85000|Bangalore|
# |        103|  Amit Kumar|Data Engineering| 65000|   Mumbai|
# +-----------+------------+----------------+------+---------+

# %%
df.sort("salary").show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# +-----------+------------+-----------------+------+---------+

# %%
df.sort(df.salary.desc()).show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# +-----------+------------+-----------------+------+---------+

# %%
df.sort("name").show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# +-----------+------------+-----------------+------+---------+

# %%
df.sort("city", "salary").show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# +-----------+------------+-----------------+------+---------+

# %%
from pyspark.sql.functions import col

df_bonus = df.withColumn("bonus", col("salary")*0.10)
df_bonus.show()
# Out:
# +-----------+------------+-----------------+------+---------+------+
# |employee_id|        name|       department|salary|     city| bonus|
# +-----------+------------+-----------------+------+---------+------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|7500.0|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|8500.0|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|6500.0|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|9500.0|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|8000.0|
# +-----------+------------+-----------------+------+---------+------+

# %%
df_tax = df.withColumn("tax", col("salary")*0.05)
df_tax.show()
# Out:
# +-----------+------------+-----------------+------+---------+------+
# |employee_id|        name|       department|salary|     city|   tax|
# +-----------+------------+-----------------+------+---------+------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|3750.0|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|4250.0|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|3250.0|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|4750.0|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|4000.0|
# +-----------+------------+-----------------+------+---------+------+

# %%
df_annualSalary = df.withColumn("annual_salary", col("salary")*12)
df_annualSalary.show()
# Out:
# +-----------+------------+-----------------+------+---------+-------------+
# |employee_id|        name|       department|salary|     city|annual_salary|
# +-----------+------------+-----------------+------+---------+-------------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|       900000|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|      1020000|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|       780000|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|      1140000|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|       960000|
# +-----------+------------+-----------------+------+---------+-------------+

# %%
df_salaryAfterBonus = df.withColumn("salary_after_bonus", col("salary") + col("salary")*0.10)
df_salaryAfterBonus.show()
# Out:
# +-----------+------------+-----------------+------+---------+------------------+
# |employee_id|        name|       department|salary|     city|salary_after_bonus|
# +-----------+------------+-----------------+------+---------+------------------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|           82500.0|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|           93500.0|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|           71500.0|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|          104500.0|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|           88000.0|
# +-----------+------------+-----------------+------+---------+------------------+

# %%
df_renamed = df.withColumnRenamed("salary", "monthly_salary")

df_renamed.show()
# Out:
# +-----------+------------+-----------------+--------------+---------+
# |employee_id|        name|       department|monthly_salary|     city|
# +-----------+------------+-----------------+--------------+---------+
# |        101|Rahul Sharma| Data Engineering|         75000|Hyderabad|
# |        102| Priya Reddy|   AI Engineering|         85000|Bangalore|
# |        103|  Amit Kumar| Data Engineering|         65000|   Mumbai|
# |        104| Sneha Patel|     Data Science|         95000|  Chennai|
# |        105|  Farhan Ali|Cloud Engineering|         80000|    Delhi|
# +-----------+------------+-----------------+--------------+---------+

# %%
df_renamed = df.withColumnRenamed("department", "team")

df_renamed.show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|             team|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# +-----------+------------+-----------------+------+---------+

# %%
from pyspark.sql.functions import *

# %%
df.agg(sum("salary")).show()
# Out:
# +-----------+
# |sum(salary)|
# +-----------+
# |     400000|
# +-----------+

# %%
df.agg(max("salary")).show()
# Out:
# +-----------+
# |max(salary)|
# +-----------+
# |      95000|
# +-----------+

# %%
df.agg(min("salary")).show()
# Out:
# +-----------+
# |min(salary)|
# +-----------+
# |      65000|
# +-----------+

# %%
df.agg(count("employee_id")).show()
# Out:
# +------------------+
# |count(employee_id)|
# +------------------+
# |                 5|
# +------------------+

# %%
df.groupBy("department").count().show()
# Out:
# +-----------------+-----+
# |       department|count|
# +-----------------+-----+
# | Data Engineering|    2|
# |   AI Engineering|    1|
# |Cloud Engineering|    1|
# |     Data Science|    1|
# +-----------------+-----+

# %%
df.groupBy("department").avg("salary").show()
# Out:
# +-----------------+-----------+
# |       department|avg(salary)|
# +-----------------+-----------+
# | Data Engineering|    70000.0|
# |   AI Engineering|    85000.0|
# |Cloud Engineering|    80000.0|
# |     Data Science|    95000.0|
# +-----------------+-----------+

# %%
df.groupBy("department").max("salary").show()
# Out:
# +-----------------+-----------+
# |       department|max(salary)|
# +-----------------+-----------+
# | Data Engineering|      75000|
# |   AI Engineering|      85000|
# |Cloud Engineering|      80000|
# |     Data Science|      95000|
# +-----------------+-----------+

# %%
df.groupBy("department").min("salary").show()
# Out:
# +-----------------+-----------+
# |       department|min(salary)|
# +-----------------+-----------+
# | Data Engineering|      65000|
# |   AI Engineering|      85000|
# |Cloud Engineering|      80000|
# |     Data Science|      95000|
# +-----------------+-----------+

# %%
df.groupBy("department").sum("salary").show()
# Out:
# +-----------------+-----------+
# |       department|sum(salary)|
# +-----------------+-----------+
# | Data Engineering|     140000|
# |   AI Engineering|      85000|
# |Cloud Engineering|      80000|
# |     Data Science|      95000|
# +-----------------+-----------+

# %%
df.select("department").distinct().show()
# Out:
# +-----------------+
# |       department|
# +-----------------+
# | Data Engineering|
# |   AI Engineering|
# |Cloud Engineering|
# |     Data Science|
# +-----------------+

# %%
df.select("city").distinct().show()
# Out:
# +---------+
# |     city|
# +---------+
# |Bangalore|
# |Hyderabad|
# |  Chennai|
# |   Mumbai|
# |    Delhi|
# +---------+

# %%
df.select("department").distinct().count()
# Out:
# 4

# %%
df.sort(col("salary").desc()).limit(3).show()
# Out:
# +-----------+-----------+-----------------+------+---------+
# |employee_id|       name|       department|salary|     city|
# +-----------+-----------+-----------------+------+---------+
# |        104|Sneha Patel|     Data Science| 95000|  Chennai|
# |        102|Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        105| Farhan Ali|Cloud Engineering| 80000|    Delhi|
# +-----------+-----------+-----------------+------+---------+

# %%
df.sort(col("salary")).limit(1).show()
# Out:
# +-----------+----------+----------------+------+------+
# |employee_id|      name|      department|salary|  city|
# +-----------+----------+----------------+------+------+
# |        103|Amit Kumar|Data Engineering| 65000|Mumbai|
# +-----------+----------+----------------+------+------+

# %%
df.filter(col("name").like("R%")).show()
# Out:
# +-----------+------------+----------------+------+---------+
# |employee_id|        name|      department|salary|     city|
# +-----------+------------+----------------+------+---------+
# |        101|Rahul Sharma|Data Engineering| 75000|Hyderabad|
# +-----------+------------+----------------+------+---------+

# %%
df.filter(col("name").like("%a%")).show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# +-----------+------------+-----------------+------+---------+

# %%
df.filter(col("department").like("%Engineering%")).show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# +-----------+------------+-----------------+------+---------+

# %%
df_salaryCategory = df.withColumn("salary_category", when(col("salary") >= 85000, "High").when(col("salary") >= 75000, "Medium").otherwise("Low"))
df_salaryCategory.show()
# Out:
# +-----------+------------+-----------------+------+---------+---------------+
# |employee_id|        name|       department|salary|     city|salary_category|
# +-----------+------------+-----------------+------+---------+---------------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|         Medium|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|           High|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|            Low|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|           High|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|         Medium|
# +-----------+------------+-----------------+------+---------+---------------+

# %%
df_new = df.withColumn("Bonus",col("salary") * 0.10).withColumn("Annual Salary",col("salary") * 12 + col("Bonus"))
df_new.show()
# Out:
# +-----------+------------+-----------------+------+---------+------+-------------+
# |employee_id|        name|       department|salary|     city| Bonus|Annual Salary|
# +-----------+------------+-----------------+------+---------+------+-------------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|7500.0|     907500.0|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|8500.0|    1028500.0|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|6500.0|     786500.0|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|9500.0|    1149500.0|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|8000.0|     968000.0|
# +-----------+------------+-----------------+------+---------+------+-------------+
