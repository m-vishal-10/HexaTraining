# %%
data = [
    (101,"Rahul",75000),
    (102,"Priya",85000),
    (103,"Amit",65000)
]

df = spark.createDataFrame(
    data,
    ["emp_id","name","salary"]
)

# %%
df.write.format("delta") \
.save("/tmp/employees_delta")

# %%
delta_df = spark.read.format("delta") \
.load("/tmp/employees_delta")

display(delta_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>salary</th></tr></thead><tbody><tr><td>101</td><td>Rahul</td><td>75000</td></tr><tr><td>102</td><td>Priya</td><td>85000</td></tr><tr><td>103</td><td>Amit</td><td>65000</td></tr></tbody></table></div>

# %%
df.write.format("delta") \
.saveAsTable("employees")

# %%
# %sql
select * from employees
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>salary</th></tr></thead><tbody><tr><td>101</td><td>Rahul</td><td>75000</td></tr><tr><td>102</td><td>Priya</td><td>85000</td></tr><tr><td>103</td><td>Amit</td><td>65000</td></tr></tbody></table></div>

# %%
# %sql

CREATE TABLE employees_delta
(
    emp_id INT,
    name STRING,
    salary INT
)
USING DELTA

# %%
# %sql

INSERT INTO employees_delta
VALUES
(101,'Rahul',75000),
(102,'Priya',85000)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>2</td><td>2</td></tr></tbody></table></div>

# %%
updates = [

(102,"Priya",90000),
(104,"Sneha",70000)

]

updates_df = spark.createDataFrame(
    updates,
    ["emp_id","name","salary"]
)

# %%
from delta.tables import DeltaTable

delta_table = DeltaTable.forPath(
    spark,
    "/tmp/employees_delta"
)

delta_table.alias("target") \
.merge(
    updates_df.alias("source"),
    "target.emp_id = source.emp_id"
) \
.whenMatchedUpdateAll() \
.whenNotMatchedInsertAll() \
.execute()
# Out:
# DataFrame[num_affected_rows: bigint, num_updated_rows: bigint, num_deleted_rows: bigint, num_inserted_rows: bigint]

# %%
# %sql
DESCRIBE HISTORY employees
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df = spark.read.format("delta").option("versionAsOf",1).load("/tmp/employees_delta")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>salary</th></tr></thead><tbody><tr><td>101</td><td>Rahul</td><td>75000</td></tr><tr><td>103</td><td>Amit</td><td>65000</td></tr><tr><td>102</td><td>Priya</td><td>90000</td></tr><tr><td>104</td><td>Sneha</td><td>70000</td></tr></tbody></table></div>

# %%
# %sql
OPTIMIZE employees
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>abfss://unity-catalog-storage@dbstoragepmjizljswznyy.dfs.core.windows.net/7405619327475617/__unitystorage/catalogs/e2071e0c-5582-42b9-98c5-8e7eb9e351e2/tables/6e28a050-268e-47f8-b231-798af3c9be75</td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 0, null, null, 0, 0, 1, 1, true, 0, 0, 1781691308749, 1781691309366, 8, 0, null, List(0, 0), null, 3, 3, 0, 0, null, null)</td></tr></tbody></table></div>

# %%
# %sql
OPTIMIZE employees ZORDER BY(salary)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>abfss://unity-catalog-storage@dbstoragepmjizljswznyy.dfs.core.windows.net/7405619327475617/__unitystorage/catalogs/e2071e0c-5582-42b9-98c5-8e7eb9e351e2/tables/6e28a050-268e-47f8-b231-798af3c9be75</td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 0, List(minCubeSize(107374182400), List(0, 0), List(1, 1160), 0, List(0, 0), 0, null), null, 0, 0, 1, 1, false, 0, 0, 1781691341083, 1781691341759, 8, 0, null, List(0, 0), null, 3, 3, 0, 0, null, null)</td></tr></tbody></table></div>

# %%
# %sql
VACUUM employees
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody><tr><td>abfss://unity-catalog-storage@dbstoragepmjizljswznyy.dfs.core.windows.net/7405619327475617/__unitystorage/catalogs/e2071e0c-5582-42b9-98c5-8e7eb9e351e2/tables/6e28a050-268e-47f8-b231-798af3c9be75</td></tr></tbody></table></div>
